# %% [markdown]
# <a href="https://colab.research.google.com/github/HectorAbraham/Ecs.-Dif.-Parciales/blob/main/Ejercicio_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  <font color=green>Ejercicio 1 </font>

# %% [markdown]
# $Ejercicio: Graficar \\ y=x^2 \\ Este\ codigo\ muestra\ la\ grafica\ de\ la\ funciòn\ cuadratica$

# %%
# Importar el módulo de Python para graficar
import matplotlib.pyplot as plt
import numpy as np

x_axis = np.linspace(-3,3)
x_axis

x_axis = np.linspace(-3,3)

def square(x): return x**2

y_axis = square(x_axis)

plt.plot(x_axis, y_axis)

# %% [markdown]
# ![cuad_b.gif.crdownload](data:application/octet-stream;base64,...)
