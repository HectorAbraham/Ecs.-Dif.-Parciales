# %% [markdown]
# <a href="https://colab.research.google.com/github/HectorAbraham/Ecs.-Dif.-Parciales/blob/main/Graficas_Sympy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sympy import *

# %% [markdown]
# # Esta celda refiere a la libreria "sympy" de la cual podremos ocupar varias herramientas para hacer calculo simbolico #

# %%
x=symbols('x')

# %%
x**2+5
# Out:
# x**2 + 5

# %% [markdown]
# #Definimos a "x" como un simbolo haciendo uso del comando symbols() y en la siguiente celda hacemos uso de este para mostrarlo escrito como una ecuación#

# %%
c1 = plotting.plot(x*x)

# %%
cl=plotting.plot(x*x,show=False)
c2=plotting.plot(x**3,show=False)

# %% [markdown]
# #La funcion plot que viene del modulo Plotting hace la grafica de las expresiones contenidas en su argumento#
# # Al añadir el argumento "show=false" la grafica de la expresión no se mostrará inmediatamente, solo se guardará en la variable correspondiente, en este caso c1 y  c2#

# %%
c1 #Indica qué es y en qué espacio de memoria está

# %%
c1.append(c2[0]) #Anida las gráficas sin los ejes

# %%
c1.show()

# %%
c1.extend(c2)

# %%
c1.show()

# %%
c2.show()

# %% [markdown]
# #esta función lo quie hace es tomar lo que esta guardado en la variable del aagurmento (c2) y añadirlo a la variable indicada (c1), en este caso fusiona las dos graficas dadas, y las muestra.#

# %%
from sympy.plotting import plot

# %%
plot(x**2)

# %%
plot(x**2,(x,-1,1))

# %%
plot(exp(x),(x,0,10))

# %% [markdown]
# #Como ya sabemos la función plot grafica las expresiones en su argumento, sin embargo, se puede modificar el intervalo del dominio de x#

# %%
plot(x,x**2,x**3, (x,-2,2))

# %%
plot(x**2,adaptative=False,nb_of_points=10) #Revisar

# %% [markdown]
# #En esta celda hacemos uso de la función plot, donde desactivamos la funcion adaptative la cual usa una cantidad de puntos pra mostrar una grafica mas suave, ahora podemos epecificar el numero de puntos los cuales estrán uniformemente distribuilos en un rango dado#

# %% [markdown]
# ### Curvas parametrizadas

# %%
from sympy import plot_parametric

# %%
s=symbols('s')

# %%
plot_parametric((cos(s)),sin(s))

# %%
plot_parametric((cos(s),sin(s)),(s,s**2),(s,-4,4))

# %%
c2[0].line_color='green'

# %%
c2.show()

# %% [markdown]
# ### Graficas 3D

# %%
from sympy.plotting import plot3d

# %%
x,y=symbols('x y')

# %%
plot3d(x*y)

# %%
plot3d(x*y, (x,-5,5),(y,-5,5))

# %%
plot3d(x*y, -x*y, (x,-5,5),(y,-5,5))

# %%
plot3d((x**2 + y**2, (x,-5,5),(y,-5,5)),(x*y,(x,-3,3),(y,-3,3)))

# %%
from sympy.plotting import plot3d_parametric_line

# %%
plot3d_parametric_line(cos(s),sin(s),s)

# %%
plot3d_parametric_line((cos(s),sin(s),s,(s,-5,5)),(sin(s),s**2,s,(s,-5,5)))

# %%
from sympy.plotting import plot3d_parametric_surface

# %%
u, v =symbols('u v')

# %%
plot3d_parametric_surface(cos(u+v),sin(u-v),u-v)

# %%
plot3d_parametric_surface(cos(v)*cos(u),cos(v)*sin(u),sin(v))

# %% [markdown]
# Funciones implícitas

# %%
from sympy import plot_implicit, symbols, Eq, And

# %%
x, y = symbols(' x y')

# %%
p1 = plot_implicit(Eq(x**2 + y**2, 5))

# %%
p6 = plot_implicit(y > x**2)

# %%
p6 = plot_implicit(And(y > x, y > -x))

# %%
from sympy.plotting import plot3d
from sympy import symbols

x, y = symbols('x y')  # Define x e y como símbolos

plot3d(x**3 + x*y + y**3, (x, -5, 5), (y, -5, 5))
